# %% [markdown]
# # Analyze Train Results
# ## Dependencies

# %%
# !pip install -r requirements.txt

# %%
import pandas as pd
import numpy as np
import joblib
import os
import json

# %%
filepath = '/home/datallah/datallah-jaymefis-gibsonce/'
sample_size = 'one'
random_state = 42

# %%
d_path = filepath + 'documentation/'

# %% [markdown]
# ## Import Results

# %%
# load df
df = pd.read_csv(d_path + 'train_scores.csv', sep = '|')

# %%
# flatten score json's into df
score_keys = json.loads(df.scores[0]).keys()
for key in score_keys:
    df[key] = df.scores.apply(lambda x: json.loads(x)[key])
df.head()
# Out:
#   model_nm                  matrix_nm                             params  \
# 0   KMeans  pos_m_X_train_one_million    {'max_iter': 200, 'tol': 9e-05}
# 1   KMeans  pos_m_X_train_one_million   {'max_iter': 200, 'tol': 0.0001}
# 2   KMeans  pos_m_X_train_one_million  {'max_iter': 200, 'tol': 0.00011}
# 3   KMeans  pos_m_X_train_one_million    {'max_iter': 300, 'tol': 9e-05}
# 4   KMeans  pos_m_X_train_one_million   {'max_iter': 300, 'tol': 0.0001}
#
#                                               scores  mean_test_accuracy  \
# 0  {"mean_test_accuracy": 0.5008629333393843, "me...            0.500863
# 1  {"mean_test_accuracy": 0.500712920260693, "mea...            0.500713
# 2  {"mean_test_accuracy": 0.5008629333516313, "me...            0.500863
# 3  {"mean_test_accuracy": 0.5008629333393843, "me...            0.500863
# 4  {"mean_test_accuracy": 0.500712920260693, "mea...            0.500713
#
#    mean_test_precision_weighted  mean_test_recall_weighted  \
# 0                      0.500859                   0.500863
# 1                      0.502142                   0.500713
# 2                      0.500859                   0.500863
# 3                      0.500859                   0.500863
# 4                      0.502142                   0.500713
#
#    mean_test_adjusted_rand_score  mean_test_adjusted_mutual_info_score
# 0                       0.000130                              0.000002
# 1                       0.000133                              0.000002
# 2                       0.000133                              0.000002
# 3                       0.000130                              0.000002
# 4                       0.000133                              0.000002

# %%
# sort results by accuracy
df['mean_test_accuracy2'] = 1 - df.mean_test_accuracy
df['mean_test_accuracy3'] = df[['mean_test_accuracy', 'mean_test_accuracy2']].max(axis = 1)
df[['model_nm', 'matrix_nm', 'params', 'mean_test_accuracy3', 'mean_test_adjusted_mutual_info_score',
    'mean_test_precision_weighted', 'mean_test_recall_weighted']].sort_values(
    by = 'mean_test_accuracy3', ascending = False).head(10)
# Out:
#      model_nm                  matrix_nm  \
# 1488     BGMM  w2v_m_X_train_one_million
# 1477     BGMM  w2v_m_X_train_one_million
# 1497     BGMM  w2v_m_X_train_one_million
# 1496     BGMM  w2v_m_X_train_one_million
# 1495     BGMM  w2v_m_X_train_one_million
# 1478     BGMM  w2v_m_X_train_one_million
# 1479     BGMM  w2v_m_X_train_one_million
# 1468     BGMM  w2v_m_X_train_one_million
# 1469     BGMM  w2v_m_X_train_one_million
# 1470     BGMM  w2v_m_X_train_one_million
#
#                                                  params  mean_test_accuracy3  \
# 1488  {'covariance_type': 'spherical', 'max_iter': 1...             0.508096
# 1477  {'covariance_type': 'spherical', 'max_iter': 1...             0.508096
# 1497  {'covariance_type': 'spherical', 'max_iter': 2...             0.508096
# 1496  {'covariance_type': 'spherical', 'max_iter': 2...             0.508096
# 1495  {'covariance_type': 'spherical', 'max_iter': 2...             0.508096
# 1478  {'covariance_type': 'spherical', 'max_iter': 1...             0.508096
# 1479  {'covariance_type': 'spherical', 'max_iter': 1...             0.508096
# 1468  {'covariance_type': 'spherical', 'max_iter': 5...             0.508096
# 1469  {'covariance_type': 'spherical', 'max_iter': 5...             0.508096
# 1470  {'covariance_type': 'spherical', 'max_iter': 5...             0.508096
#
#       mean_test_adjusted_mutual_info_score  mean_test_precision_weighted  \
# 1488                              0.000329                      0.485678
# 1477                              0.000329                      0.485678
# 1497                              0.000329                      0.485678
# 1496                              0.000329                      0.485678
# 1495                              0.000329                      0.485678
# 1478                              0.000329                      0.485678
# 1479                              0.000329                      0.485678
# 1468                              0.000329                      0.485678
# 1469                              0.000329                      0.485678
# 1470                              0.000329                      0.485678
#
#       mean_test_recall_weighted
# 1488                   0.491904
# 1477                   0.491904
# 1497                   0.491904
# 1496                   0.491904
# 1495                   0.491904
# 1478                   0.491904
# 1479                   0.491904
# 1468                   0.491904
# 1469                   0.491904
# 1470                   0.491904
